# %% [markdown]
# <a href="https://colab.research.google.com/github/hentiamenty/CNN-cars/blob/main/Cars_recognizing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# loading frameworks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
import gdown
# %matplotlib inline

# %%
# Loading dataset
gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l5/middle_fmr.zip', None, quiet=True)
# unpacking dataset
# !unzip -qo "middle_fmr.zip" -d /content/cars
IMAGE_PATH = '/content/cars/'

# %%
# defining the list and number of classes
CLASS_LIST = sorted(os.listdir(IMAGE_PATH))
CLASS_COUNT = len(CLASS_LIST)
print(f'class number: {CLASS_COUNT}, class labels: {CLASS_LIST}')
# Out:
# class number: 3, class labels: ['Ferrari', 'Mercedes', 'Renault']

# %%
# Drowing random picture from each class
import random
fig, axs = plt.subplots(1, CLASS_COUNT, figsize=(25, 5))
for i in range(CLASS_COUNT):
    car_path = f'{IMAGE_PATH}{CLASS_LIST[i]}/'  
    image_path = car_path + random.choice(os.listdir(car_path))
    axs[i].set_title(CLASS_LIST[i])
    axs[i].imshow(Image.open(image_path))  
    axs[i].axis('off')
plt.show()
